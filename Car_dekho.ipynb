# %%
import pandas as pd 
import numpy as np
import ast

# %% [markdown]
# Chennai

# %%
import pandas as pd

# Define the file path to your Excel file
file_path = r'C:\Users\Ramanathan\Desktop\Capstone_3\chennai_cars.xlsx'

# Read the Excel file into a DataFrame
chennai_data = pd.read_excel(file_path)

# Display the first row of the DataFrame, which includes the column headers
print(chennai_data.head(1))

# Optionally, display the DataFrame in a well-formatted table view (only useful in Jupyter or notebooks)
from IPython.display import display
display(chennai_data.head(1))  # Displays a neat table format in notebooks
# Out:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                        new_car_specs  \
# 0  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                            car_links
# 0  https://www.cardekho.com/used-car-details/used...
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                        new_car_specs  \
# ...

# %%
fuel_type=[]
body_type=[]
kilometer=[]
transmission_type=[]
owner_no=[]
brand=[]
model=[]
model_year=[]
price=[]
registration_year=[]
seats_count=[]
RDO_no=[]
engine_cc=[]
mileage=[]
max_power=[]
color=[]
car_engine_cc=[]
car_engine_cc1=[]
gear_box=[]
seating_capacity=[]
top_speed=[]
pickup_speed=[]
tyre_type=[]

for i in range(chennai_data.shape[0]):
    dic_1=chennai_data['new_car_detail'][i]
    dic_2=chennai_data['new_car_overview'][i]
    dic_3=chennai_data['new_car_specs'][i]
    
    res = ast.literal_eval(dic_1)
    res_1 = ast.literal_eval(dic_2)
    res_2 = ast.literal_eval(dic_3)
    
    fuel_type.append(res['ft'])
    body_type.append(res['bt'])
    kilometer.append(res['km'])
    transmission_type.append(res['transmission'])
    owner_no.append(res['ownerNo'])
    brand.append(res['oem'])
    model.append(res['model'])
    model_year.append(res['modelYear'])
    price.append(float(res['price'][2:-5])*100000)
    
    try:
        registration_year.append(res_1['top'][0]['value'][-4:])
    except:
        registration_year.append(np.nan)
    try:
        seats_count.append(res_1['top'][3]['value'][0])
    except:
        seats_count.append(np.nan)
    try:
        RDO_no.append(res_1['top'][5]['value'])
    except:
        RDO_no.append(np.nan)
    try:
        engine_cc.append(res_1['top'][7]['value'][:-3])
    except:
        engine_cc.append(np.nan)
    mileage.append(res_2['top'][0]['value'][:-5])
    try:
        max_power.append(res_2['top'][2]['value'][:-3])
    except:
        max_power.append(np.nan)
    color.append(res_2['data'][0]['list'][0]['value'])
    try:
        if (res_2['data'][0]['list'][2]['value']).isnumeric():
            car_engine_cc.append(res_2['data'][0]['list'][2]['value'])
        else:
            car_engine_cc.append(res_2['data'][0]['list'][1]['value'])
    except:
        car_engine_cc.append(np.nan)
    try:
        gear_box.append(res_2['data'][2]['list'][0]['value'][0])
    except:
        gear_box.append(np.nan)
    try:
        seating_capacity.append(res_2['data'][2]['list'][2]['value'])
    except:
        seating_capacity.append(np.nan)
    try:
        top_speed.append(res_2['data'][2]['list'][7]['value'])
    except:
        top_speed.append(np.nan)
    try:
        pickup_speed.append(res_2['data'][2]['list'][8]['value'])
    except:
        pickup_speed.append(np.nan)
    try:
        tyre_type.append(res_2['data'][2]['list'][9]['value'])
    except:
        tyre_type.append(np.nan)
        
        
chennai_data['fuel_type']=fuel_type
chennai_data['body_type']=body_type
chennai_data['kilometer']=kilometer
chennai_data['transmission_type']=transmission_type
chennai_data['owner_no']=owner_no
chennai_data['brand']=brand
chennai_data['model']=model
chennai_data['model_year']=model_year
chennai_data['price']=price
chennai_data['registration_year']=registration_year
chennai_data['seats_count']=seats_count
chennai_data['RDO_no']=RDO_no
chennai_data['engine_cc']=engine_cc
chennai_data['mileage']=mileage
chennai_data['max_power(bhp)']=max_power
chennai_data['color']=color
chennai_data['car_engine_cc']=car_engine_cc
chennai_data['gear_box']=gear_box
chennai_data['seating_capacity']=seating_capacity
chennai_data['top_speed']=top_speed
chennai_data['pickup_speed']=pickup_speed
chennai_data['tyre_type']=tyre_type

# %%
chennai_data.columns
# Out:
# Index(['new_car_detail', 'new_car_overview', 'new_car_feature',
#        'new_car_specs', 'car_links', 'fuel_type', 'body_type', 'kilometer',
#        'transmission_type', 'owner_no', 'brand', 'model', 'model_year',
#        'price', 'registration_year', 'seats_count', 'RDO_no', 'engine_cc',
#        'mileage', 'max_power(bhp)', 'color', 'car_engine_cc', 'gear_box',
#        'seating_capacity', 'top_speed', 'pickup_speed', 'tyre_type'],
#       dtype='object')

# %%
chennai_da=chennai_data[['fuel_type', 'body_type', 'kilometer',
       'transmission_type', 'owner_no', 'brand', 'model', 'model_year',
       'price', 'registration_year', 'seats_count', 'RDO_no', 'car_engine_cc',
       'mileage', 'color', 'gear_box']]
chennai_da.head()
# Out:
#   fuel_type  body_type kilometer transmission_type  owner_no    brand  \
# 0    Petrol        SUV    20,000         Automatic         1      Kia
# 1    Petrol   Minivans    20,687            Manual         1   Maruti
# 2    Petrol        SUV    30,000            Manual         1   Nissan
# 3    Petrol  Hatchback    59,247            Manual         1  Hyundai
# 4    Petrol  Hatchback    50,000            Manual         1    Honda
#
#             model  model_year      price registration_year seats_count RDO_no  \
# 0       Kia Sonet        2022  1150000.0              2022           5   TN02
# 1     Maruti Eeco        2015   415000.0              2015           7   TN04
# 2  Nissan Magnite        2021   750000.0              2021           5   TN22
# 3     Hyundai i10        2015   398000.0              2015           5   TN11
# 4      Honda Jazz        2015   550000.0              2015           5   KA03
#
#   car_engine_cc mileage   color gear_box
# ...

# %%
chennai_da['car_engine_cc'].unique()
# Out:
# array(['998', '1196', '999', '1086', '1199', '2143', '1995', '1497',
#        '1197', '1956', '2755', '1198', '1248', '0', '1582', '1984',
#        '2694', '1498', '1298', '1461', '1798', '1364', '1591', '1968',
#        '2967', '2393', '2993', '1368', '2198', '1373', '1598', '2179',
#        '1462', '1451', '1194', '1991', '1493', '1998', '4663', '2987',
#        '796', '1186', '1799', '1950', '1496', '2925', '1396', '1353',
#        '799', '1405', '814', '2494', nan, '1399', '1997', '1047', '2999',
#        '1499', '2184', '1896', '1999', '1969', '1495', '1390', '1120',
#        '1482', '2523', '2354', '624', '793', '936', '4134', '993', '2499',
#        '2982', '1796', '1422', '1172', '1468', '1599', '1586', '1193',
#        '2199', '1330', '2696', '2400', '2477', '2998', '2997', '2995',
#        '1395', '2487'], dtype=object)

# %% [markdown]
# Bangalore

# %%
import pandas as pd

# Define the file path to your Excel file
file_path = r'C:\Users\Ramanathan\Desktop\Capstone_3\bangalore_cars.xlsx'

# Read the Excel file into a DataFrame
bangalore_data = pd.read_excel(file_path)

# Display the first row of the DataFrame, which includes the column headers
print(bangalore_data.head(1))

# Optionally, display the DataFrame in a well-formatted table view (only useful in Jupyter or notebooks)
from IPython.display import display
display(bangalore_data.head(1))  # Displays a neat table format in notebooks
# Out:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                        new_car_specs  \
# 0  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                            car_links
# 0  https://www.cardekho.com/used-car-details/used...
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                        new_car_specs  \
# ...

# %%
bangalore_data['new_car_overview'][53]
# Out:
# "{'heading': 'Car overview', 'top': [{'key': 'Registration Year', 'value': '2008', 'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/registrationYear.svg'}, {'key': 'Insurance Validity', 'value': 'Third Party insurance', 'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/insuranceValidity.svg'}, {'key': 'Fuel Type', 'value': 'Petrol', 'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/fuel.svg'}, {'key': 'Seats', 'value': '5 Seats', 'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/seats.svg'}, {'key': 'Kms Driven', 'value': '60,000 Kms', 'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/kmsDriven.svg'}, {'key': 'Ownership', 'value': 'Second Owner', 'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/ownership.svg'}, {'key': 'Engine Displacement', 'value': '796 cc', 'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/engineDisplacement.svg'}, {'key': 'Transmission', 'value': 'Manual', 'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/transmission.svg'}, {'ke
# ...

# %%
fuel_type=[]
body_type=[]
kilometer=[]
transmission_type=[]
owner_no=[]
brand=[]
model=[]
model_year=[]
price=[]
registration_year=[]
seats_count=[]
RDO_no=[]
engine_cc=[]
mileage=[]
max_power=[]
color=[]
car_engine_cc=[]
gear_box=[]
seating_capacity=[]
top_speed=[]
pickup_speed=[]
tyre_type=[]

for i in range(bangalore_data.shape[0]):
    dic_1=bangalore_data['new_car_detail'][i]
    dic_2=bangalore_data['new_car_overview'][i]
    dic_3=bangalore_data['new_car_specs'][i]
    
    res = ast.literal_eval(dic_1)
    res_1 = ast.literal_eval(dic_2)
    res_2 = ast.literal_eval(dic_3)
    
    fuel_type.append(res['ft'])
    body_type.append(res['bt'])
    kilometer.append(res['km'])
    transmission_type.append(res['transmission'])
    owner_no.append(res['ownerNo'])
    brand.append(res['oem'])
    model.append(res['model'])
    model_year.append(res['modelYear'])
    price.append(float(res['price'][2:-5])*100000)
    
    try:
        registration_year.append(res_1['top'][0]['value'][-4:])
    except:
        registration_year.append(np.nan)
    try:
        seats_count.append(res_1['top'][3]['value'][0])
    except:
        seats_count.append(np.nan)
    try:
        RDO_no.append(res_1['top'][5]['value'])
    except:
        RDO_no.append(np.nan)
    try:
        engine_cc.append(res_1['top'][7]['value'][:-3])
    except:
        engine_cc.append(np.nan)
    mileage.append(res_2['top'][0]['value'][:-5])
    try:
        max_power.append(res_2['top'][2]['value'][:-3])
    except:
        max_power.append(np.nan)
    color.append(res_2['data'][0]['list'][0]['value'])
    try:
        if (res_2['data'][0]['list'][2]['value']).isnumeric():
            car_engine_cc.append(res_2['data'][0]['list'][2]['value'])
        else:
            car_engine_cc.append(res_2['data'][0]['list'][1]['value'])
    except:
        car_engine_cc.append(np.nan)
    try:
        gear_box.append(res_2['data'][2]['list'][0]['value'][0])
    except:
        gear_box.append(np.nan)
    try:
        seating_capacity.append(res_2['data'][2]['list'][2]['value'])
    except:
        seating_capacity.append(np.nan)
    try:
        top_speed.append(res_2['data'][2]['list'][7]['value'])
    except:
        top_speed.append(np.nan)
    try:
        pickup_speed.append(res_2['data'][2]['list'][8]['value'])
    except:
        pickup_speed.append(np.nan)
    try:
        tyre_type.append(res_2['data'][2]['list'][9]['value'])
    except:
        tyre_type.append(np.nan)

        
bangalore_data['fuel_type']=fuel_type
bangalore_data['body_type']=body_type
bangalore_data['kilometer']=kilometer
bangalore_data['transmission_type']=transmission_type
bangalore_data['owner_no']=owner_no
bangalore_data['brand']=brand
bangalore_data['model']=model
bangalore_data['model_year']=model_year
bangalore_data['price']=price
bangalore_data['registration_year']=registration_year
bangalore_data['seats_count']=seats_count
bangalore_data['RDO_no']=RDO_no
bangalore_data['engine_cc']=engine_cc
bangalore_data['mileage']=mileage
bangalore_data['max_power(bhp)']=max_power
bangalore_data['color']=color
bangalore_data['car_engine_cc']=car_engine_cc
bangalore_data['gear_box']=gear_box
bangalore_data['seating_capacity']=seating_capacity
bangalore_data['top_speed']=top_speed
bangalore_data['pickup_speed']=pickup_speed
bangalore_data['tyre_type']=tyre_type

# %%
res_2= ast.literal_eval(bangalore_data['new_car_specs'][16])
res_2['data'][0]['list'][1]['value']
# # res_2['data'][2]['list'][8]['value']
# Out:
# '1950'

# %%
bangalore_data.columns
# Out:
# Index(['new_car_detail', 'new_car_overview', 'new_car_feature',
#        'new_car_specs', 'car_links', 'fuel_type', 'body_type', 'kilometer',
#        'transmission_type', 'owner_no', 'brand', 'model', 'model_year',
#        'price', 'registration_year', 'seats_count', 'RDO_no', 'engine_cc',
#        'mileage', 'max_power(bhp)', 'color', 'car_engine_cc', 'gear_box',
#        'seating_capacity', 'top_speed', 'pickup_speed', 'tyre_type'],
#       dtype='object')

# %%
bangalore_da=bangalore_data[['fuel_type', 'body_type', 'kilometer',
       'transmission_type', 'owner_no', 'brand', 'model', 'model_year',
       'price', 'registration_year', 'seats_count', 'RDO_no', 'car_engine_cc',
       'mileage', 'color', 'gear_box']]
bangalore_da.head(60)
# Out:
#    fuel_type  body_type kilometer transmission_type  owner_no          brand  \
# 0     Petrol  Hatchback  1,20,000            Manual         3         Maruti
# 1     Petrol        SUV    32,706            Manual         2           Ford
# 2     Petrol  Hatchback    11,949            Manual         1           Tata
# 3     Petrol      Sedan    17,794            Manual         1        Hyundai
# 4     Diesel        SUV    60,000            Manual         1         Maruti
# 5     Diesel        SUV    20,000            Manual         1           Jeep
# 6     Petrol  Hatchback    37,772            Manual         1         Datsun
# 7     Petrol        SUV    30,000         Automatic         1        Hyundai
# 8     Petrol      Sedan    37,000         Automatic         1         Maruti
# 9     Petrol  Hatchback    11,949            Manual         1           Tata
# 10    Petrol  Hatchback    50,000            Manual         1         Maruti
# ...

# %%
bangalore_da['car_engine_cc'].unique()
# Out:
# array(['998', '1497', '1199', '1197', '1248', '1956', '1198', '1462',
#        '2179', '1950', '1396', '1995', '1498', '4663', '1086', '1991',
#        '1968', '1998', '2982', '1461', '1797', '796', '1353', '2925',
#        '2987', '2967', '999', '1341', '1496', '1582', '1798', '1120',
#        '1969', '1451', '814', '1999', '1591', '1397', '1368', '1598',
#        '3198', '1196', '2993', '2755', '2143', '2354', '1332', '2199',
#        '1997', '1499', '2148', '2696', '1364', '2494', '1373', '1299',
#        '1061', '1493', '2497', '1495', '1590', '1896', '1330', '1781',
#        '1390', '1194', '2953', '1399', '1595', 'Power', '2496',
#        '210AH Lithium Ion', '0', '1984', nan, '2694', '1298', '2362',
#        '2198', '1599', '993', '2393', '1389', '1597', '2498', '2523',
#        '1586', '995', '2499', '2998', '72', '1589', '624', '1596', '799',
#        '3597', '2184', '1405', '5000', '1422', '1047', '2200', '2996',
#        '1108', '2400', '1996', '1395'], dtype=object)

# %% [markdown]
# Delhi

# %%
import pandas as pd

# Define the file path to your Excel file
file_path = r'C:\Users\Ramanathan\Desktop\Capstone_3\delhi_cars.xlsx'

# Read the Excel file into a DataFrame
delhi_data = pd.read_excel(file_path)

# Display the first row of the DataFrame, which includes the column headers
print(delhi_data.head(1))

# Optionally, display the DataFrame in a well-formatted table view (only useful in Jupyter or notebooks)
from IPython.display import display
display(delhi_data.head(1))  # Displays a neat table format in notebooks
# Out:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                        new_car_specs  \
# 0  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                            car_links
# 0  https://www.cardekho.com/used-car-details/used...
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                        new_car_specs  \
# ...

# %%
fuel_type=[]
body_type=[]
kilometer=[]
transmission_type=[]
owner_no=[]
brand=[]
model=[]
model_year=[]
price=[]
registration_year=[]
seats_count=[]
RDO_no=[]
engine_cc=[]
mileage=[]
max_power=[]
color=[]
car_engine_cc=[]
gear_box=[]
seating_capacity=[]
top_speed=[]
pickup_speed=[]
tyre_type=[]

for i in range(delhi_data.shape[0]):
    dic_1=delhi_data['new_car_detail'][i]
    dic_2=delhi_data['new_car_overview'][i]
    dic_3=delhi_data['new_car_specs'][i]
    
    res = ast.literal_eval(dic_1)
    res_1 = ast.literal_eval(dic_2)
    res_2 = ast.literal_eval(dic_3)
    
    fuel_type.append(res['ft'])
    body_type.append(res['bt'])
    kilometer.append(res['km'])
    transmission_type.append(res['transmission'])
    owner_no.append(res['ownerNo'])
    brand.append(res['oem'])
    model.append(res['model'])
    model_year.append(res['modelYear'])
    price.append(float(res['price'][2:-5])*100000)
    
    try:
        registration_year.append(res_1['top'][0]['value'][-4:])
        
    except:
        registration_year.append(np.nan)
    try:
        seats_count.append(res_1['top'][3]['value'][0])
    except:
        seats_count.append(np.nan)
    try:
        RDO_no.append(res_1['top'][5]['value'])
    except:
        RDO_no.append(np.nan)
    try:
        engine_cc.append(res_1['top'][7]['value'][:-3])
    except:
        engine_cc.append(np.nan)
    mileage.append(res_2['top'][0]['value'][:-5])
    try:
        max_power.append(res_2['top'][2]['value'][:-3])
    except:
        max_power.append(np.nan)
    color.append(res_2['data'][0]['list'][0]['value'])
    try:
        if (res_2['data'][0]['list'][2]['value']).isnumeric():
            car_engine_cc.append(res_2['data'][0]['list'][2]['value'])
        else:
            car_engine_cc.append(res_2['data'][0]['list'][1]['value'])
    except:
        car_engine_cc.append(np.nan)
    try:
        gear_box.append(res_2['data'][2]['list'][0]['value'][0])
    except:
        gear_box.append(np.nan)
    try:
        seating_capacity.append(res_2['data'][2]['list'][2]['value'])
    except:
        seating_capacity.append(np.nan)
    try:
        top_speed.append(res_2['data'][2]['list'][7]['value'])
    except:
        top_speed.append(np.nan)
    try:
        pickup_speed.append(res_2['data'][2]['list'][8]['value'])
    except:
        pickup_speed.append(np.nan)
    try:
        tyre_type.append(res_2['data'][2]['list'][9]['value'])
    except:
        tyre_type.append(np.nan)
        
delhi_data['fuel_type']=fuel_type
delhi_data['body_type']=body_type
delhi_data['kilometer']=kilometer
delhi_data['transmission_type']=transmission_type
delhi_data['owner_no']=owner_no
delhi_data['brand']=brand
delhi_data['model']=model
delhi_data['model_year']=model_year
delhi_data['price']=price
delhi_data['registration_year']=registration_year
delhi_data['seats_count']=seats_count
delhi_data['RDO_no']=RDO_no
delhi_data['engine_cc']=engine_cc
delhi_data['mileage']=mileage
delhi_data['max_power(bhp)']=max_power
delhi_data['color']=color
delhi_data['car_engine_cc']=car_engine_cc
delhi_data['gear_box']=gear_box
delhi_data['seating_capacity']=seating_capacity
delhi_data['top_speed']=top_speed
delhi_data['pickup_speed']=pickup_speed
delhi_data['tyre_type']=tyre_type

# %%
delhi_data.columns
# Out:
# Index(['new_car_detail', 'new_car_overview', 'new_car_feature',
#        'new_car_specs', 'car_links', 'fuel_type', 'body_type', 'kilometer',
#        'transmission_type', 'owner_no', 'brand', 'model', 'model_year',
#        'price', 'registration_year', 'seats_count', 'RDO_no', 'engine_cc',
#        'mileage', 'max_power(bhp)', 'color', 'car_engine_cc', 'gear_box',
#        'seating_capacity', 'top_speed', 'pickup_speed', 'tyre_type'],
#       dtype='object')

# %%
delhi_da=delhi_data[['fuel_type', 'body_type', 'kilometer',
       'transmission_type', 'owner_no', 'brand', 'model', 'model_year',
       'price', 'registration_year', 'seats_count', 'RDO_no', 'car_engine_cc',
       'mileage',  'color', 'gear_box']]
delhi_da.head()
# Out:
#   fuel_type  body_type kilometer transmission_type  owner_no          brand  \
# 0    Diesel        SUV    10,000         Automatic         1            Kia
# 1    Petrol        SUV    57,437            Manual         2        Hyundai
# 2    Petrol        SUV     8,000         Automatic         1  Mercedes-Benz
# 3    Petrol  Hatchback    28,151            Manual         2         Maruti
# 4    Petrol        SUV    60,000            Manual         1        Hyundai
#
#                model  model_year      price registration_year seats_count  \
# 0         Kia Seltos        2022  1900000.0              2022           5
# 1      Hyundai Creta        2016   762000.0              2016           5
# 2  Mercedes-Benz GLC        2020  5600000.0              2020           5
# 3       Maruti Swift        2018   523000.0              2019           5
# 4      Hyundai Creta        2017   765000.0              2017           5
#
#         RDO_no car_engine_cc mileage   color gear_box
# ...

# %% [markdown]
# Hydrabad

# %%
import pandas as pd

# Define the file path to your Excel file
file_path = r'C:\Users\Ramanathan\Desktop\Capstone_3\hyderabad_cars.xlsx'

# Read the Excel file into a DataFrame
hyderabad_data = pd.read_excel(file_path)

# Display the first row of the DataFrame, which includes the column headers
print(hyderabad_data.head(1))

# Optionally, display the DataFrame in a well-formatted table view (only useful in Jupyter or notebooks)
from IPython.display import display
display(hyderabad_data.head(1))  # Displays a neat table format in notebooks
# Out:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                        new_car_specs  \
# 0  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                            car_links
# 0  https://www.cardekho.com/used-car-details/used...
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                        new_car_specs  \
# ...

# %%
hyderabad_data['new_car_detail'][1200]
# Out:
# "{'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '72,812', 'transmission': 'Automatic', 'ownerNo': 2, 'owner': '2nd Owner', 'oem': 'Tata', 'model': 'Tata Nexon', 'modelYear': 2020, 'centralVariantId': 7403, 'variantName': 'XZA Plus (O) AMT', 'price': '₹ 9.69 Lakh', 'priceActual': '₹ 10.81 Lakh', 'priceSaving': '', 'priceFixedText': None, 'trendingText': {'imgUrl': 'https://stimg.cardekho.com/used-cars/common/icons/trending.svg', 'heading': 'Trending Car!', 'desc': 'High chances of sale in next 6 days'}}"

# %%
fuel_type=[]
body_type=[]
kilometer=[]
transmission_type=[]
owner_no=[]
brand=[]
model=[]
model_year=[]
price=[]
registration_year=[]
seats_count=[]
RDO_no=[]
engine_cc=[]
mileage=[]
max_power=[]
color=[]
car_engine_cc=[]
car_engine_cc1=[]
gear_box=[]
seating_capacity=[]
top_speed=[]
pickup_speed=[]
tyre_type=[]

for i in range(hyderabad_data.shape[0]):
    dic_1=hyderabad_data['new_car_detail'][i]
    dic_2=hyderabad_data['new_car_overview'][i]
    dic_3=hyderabad_data['new_car_specs'][i]
    
    res = ast.literal_eval(dic_1)
    res_1 = ast.literal_eval(dic_2)
    res_2 = ast.literal_eval(dic_3)
    
    fuel_type.append(res['ft'])
    body_type.append(res['bt'])
    kilometer.append(res['km'])
    transmission_type.append(res['transmission'])
    owner_no.append(res['ownerNo'])
    brand.append(res['oem'])
    model.append(res['model'])
    model_year.append(res['modelYear'])
    price.append(float(res['price'][2:-5])*100000)
    
    try:
        registration_year.append(res_1['top'][0]['value'][-4:])
    except:
        registration_year.append(np.nan)
    try:
        seats_count.append(res_1['top'][3]['value'][0])
    except:
        seats_count.append(np.nan)
    try:
        RDO_no.append(res_1['top'][5]['value'])
    except:
        RDO_no.append(np.nan)
    try:
        engine_cc.append(res_1['top'][7]['value'][:-3])
    except:
        engine_cc.append(np.nan)
    mileage.append(res_2['top'][0]['value'][:-5])
    try:
        max_power.append(res_2['top'][2]['value'][:-3])
    except:
        max_power.append(np.nan)
    color.append(res_2['data'][0]['list'][0]['value'])
    try:
        if (res_2['data'][0]['list'][2]['value']).isnumeric():
            car_engine_cc.append(res_2['data'][0]['list'][2]['value'])
        else:
            car_engine_cc.append(res_2['data'][0]['list'][1]['value'])
    except:
        car_engine_cc.append(np.nan)
    try:
        gear_box.append(res_2['data'][2]['list'][0]['value'][0])
    except:
        gear_box.append(np.nan)
    try:
        seating_capacity.append(res_2['data'][2]['list'][2]['value'])
    except:
        seating_capacity.append(np.nan)
    try:
        top_speed.append(res_2['data'][2]['list'][7]['value'])
    except:
        top_speed.append(np.nan)
    try:
        pickup_speed.append(res_2['data'][2]['list'][8]['value'])
    except:
        pickup_speed.append(np.nan)
    try:
        tyre_type.append(res_2['data'][2]['list'][9]['value'])
    except:
        tyre_type.append(np.nan)

        
hyderabad_data['fuel_type']=fuel_type
hyderabad_data['body_type']=body_type
hyderabad_data['kilometer']=kilometer
hyderabad_data['transmission_type']=transmission_type
hyderabad_data['owner_no']=owner_no
hyderabad_data['brand']=brand
hyderabad_data['model']=model
hyderabad_data['model_year']=model_year
hyderabad_data['price']=price
hyderabad_data['registration_year']=registration_year
hyderabad_data['seats_count']=seats_count
hyderabad_data['RDO_no']=RDO_no
hyderabad_data['engine_cc']=engine_cc
hyderabad_data['mileage']=mileage
hyderabad_data['max_power(bhp)']=max_power
hyderabad_data['color']=color
hyderabad_data['car_engine_cc']=car_engine_cc
hyderabad_data['gear_box']=gear_box
hyderabad_data['seating_capacity']=seating_capacity
hyderabad_data['top_speed']=top_speed
hyderabad_data['pickup_speed']=pickup_speed
hyderabad_data['tyre_type']=tyre_type

# %%
hyderabad_data.columns
# Out:
# Index(['new_car_detail', 'new_car_overview', 'new_car_feature',
#        'new_car_specs', 'car_links', 'fuel_type', 'body_type', 'kilometer',
#        'transmission_type', 'owner_no', 'brand', 'model', 'model_year',
#        'price', 'registration_year', 'seats_count', 'RDO_no', 'engine_cc',
#        'mileage', 'max_power(bhp)', 'color', 'car_engine_cc', 'gear_box',
#        'seating_capacity', 'top_speed', 'pickup_speed', 'tyre_type'],
#       dtype='object')

# %%
hyderabad_da=hyderabad_data[['fuel_type', 'body_type', 'kilometer',
       'transmission_type', 'owner_no', 'brand', 'model', 'model_year',
       'price', 'registration_year', 'seats_count', 'RDO_no', 'car_engine_cc',
       'mileage',  'color', 'gear_box']]
hyderabad_da.head()
# Out:
#   fuel_type  body_type kilometer transmission_type  owner_no       brand  \
# 0    Petrol  Hatchback    20,000         Automatic         1  Volkswagen
# 1    Petrol  Hatchback    85,582            Manual         2     Hyundai
# 2    Petrol        SUV    10,000            Manual         1     Hyundai
# 3    Petrol  Hatchback    50,750            Manual         1      Maruti
# 4    Petrol        SUV    10,000         Automatic         1    Mahindra
#
#              model  model_year      price registration_year seats_count  \
# 0  Volkswagen Polo        2022  1044000.0              2022           5
# 1      Hyundai EON        2014   260000.0              2014           5
# 2    Hyundai Venue        2023   955000.0              2023           5
# 3    Maruti Baleno        2017   671000.0              2017           5
# 4    Mahindra Thar        2022  1900000.0              2022           4
#
#         RDO_no car_engine_cc mileage   color gear_box
# ...

# %% [markdown]
# Jaipur

# %%
import pandas as pd

# Define the file path to your Excel file
file_path = r'C:\Users\Ramanathan\Desktop\Capstone_3\jaipur_cars.xlsx'

# Read the Excel file into a DataFrame
jaipur_data = pd.read_excel(file_path)

# Display the first row of the DataFrame, which includes the column headers
print(jaipur_data.head(1))

# Optionally, display the DataFrame in a well-formatted table view (only useful in Jupyter or notebooks)
from IPython.display import display
display(jaipur_data.head(1))  # Displays a neat table format in notebooks
# Out:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Diesel', 'bt': 'Hatchback', '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                        new_car_specs  \
# 0  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                            car_links
# 0  https://www.cardekho.com/used-car-details/used...
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Diesel', 'bt': 'Hatchback', '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                        new_car_specs  \
# ...

# %%
fuel_type=[]
body_type=[]
kilometer=[]
transmission_type=[]
owner_no=[]
brand=[]
model=[]
model_year=[]
price=[]
registration_year=[]
seats_count=[]
RDO_no=[]
engine_cc=[]
mileage=[]
max_power=[]
color=[]
car_engine_cc=[]
gear_box=[]
seating_capacity=[]
top_speed=[]
pickup_speed=[]
tyre_type=[]

for i in range(jaipur_data.shape[0]):
    dic_1=jaipur_data['new_car_detail'][i]
    dic_2=jaipur_data['new_car_overview'][i]
    dic_3=jaipur_data['new_car_specs'][i]
    
    res = ast.literal_eval(dic_1)
    res_1 = ast.literal_eval(dic_2)
    res_2 = ast.literal_eval(dic_3)
    
    fuel_type.append(res['ft'])
    body_type.append(res['bt'])
    kilometer.append(res['km'])
    transmission_type.append(res['transmission'])
    owner_no.append(res['ownerNo'])
    brand.append(res['oem'])
    model.append(res['model'])
    model_year.append(res['modelYear'])
    price.append(float(res['price'][2:-5])*100000)
    
    try:
        registration_year.append(res_1['top'][0]['value'][-4:])
    except:
        registration_year.append(np.nan)
    try:
        seats_count.append(res_1['top'][3]['value'][0])
    except:
        seats_count.append(np.nan)
    try:
        RDO_no.append(res_1['top'][5]['value'])
    except:
        RDO_no.append(np.nan)
    try:
        engine_cc.append(res_1['top'][7]['value'][:-3])
    except:
        engine_cc.append(np.nan)
    mileage.append(res_2['top'][0]['value'][:-5])
    try:
        max_power.append(res_2['top'][2]['value'][:-3])
    except:
        max_power.append(np.nan)
    color.append(res_2['data'][0]['list'][0]['value'])
    try:
        if (res_2['data'][0]['list'][2]['value']).isnumeric():
            car_engine_cc.append(res_2['data'][0]['list'][2]['value'])
        else:
            car_engine_cc.append(res_2['data'][0]['list'][1]['value'])
    except:
        car_engine_cc.append(np.nan)
    try:
        gear_box.append(res_2['data'][2]['list'][0]['value'][0])
    except:
        gear_box.append(np.nan)
    try:
        seating_capacity.append(res_2['data'][2]['list'][2]['value'])
    except:
        seating_capacity.append(np.nan)
    try:
        top_speed.append(res_2['data'][2]['list'][7]['value'])
    except:
        top_speed.append(np.nan)
    try:
        pickup_speed.append(res_2['data'][2]['list'][8]['value'])
    except:
        pickup_speed.append(np.nan)
    try:
        tyre_type.append(res_2['data'][2]['list'][9]['value'])
    except:
        tyre_type.append(np.nan)

        
jaipur_data['fuel_type']=fuel_type
jaipur_data['body_type']=body_type
jaipur_data['kilometer']=kilometer
jaipur_data['transmission_type']=transmission_type
jaipur_data['owner_no']=owner_no
jaipur_data['brand']=brand
jaipur_data['model']=model
jaipur_data['model_year']=model_year
jaipur_data['price']=price
jaipur_data['registration_year']=registration_year
jaipur_data['seats_count']=seats_count
jaipur_data['RDO_no']=RDO_no
jaipur_data['engine_cc']=engine_cc
jaipur_data['mileage']=mileage
jaipur_data['max_power(bhp)']=max_power
jaipur_data['color']=color
jaipur_data['car_engine_cc']=car_engine_cc
jaipur_data['gear_box']=gear_box
jaipur_data['seating_capacity']=seating_capacity
jaipur_data['top_speed']=top_speed
jaipur_data['pickup_speed']=pickup_speed
jaipur_data['tyre_type']=tyre_type

# %%
jaipur_data.columns
# Out:
# Index(['new_car_detail', 'new_car_overview', 'new_car_feature',
#        'new_car_specs', 'car_links', 'fuel_type', 'body_type', 'kilometer',
#        'transmission_type', 'owner_no', 'brand', 'model', 'model_year',
#        'price', 'registration_year', 'seats_count', 'RDO_no', 'engine_cc',
#        'mileage', 'max_power(bhp)', 'color', 'car_engine_cc', 'gear_box',
#        'seating_capacity', 'top_speed', 'pickup_speed', 'tyre_type'],
#       dtype='object')

# %%
jaipur_da=jaipur_data[['fuel_type', 'body_type', 'kilometer',
       'transmission_type', 'owner_no', 'brand', 'model', 'model_year',
       'price', 'registration_year', 'seats_count', 'RDO_no', 'car_engine_cc',
       'mileage', 'color', 'gear_box']]
jaipur_da.head()
# Out:
#   fuel_type  body_type kilometer transmission_type  owner_no    brand  \
# 0    Diesel  Hatchback  1,20,000            Manual         2  Hyundai
# 1    Petrol  Hatchback    66,951            Manual         1   Maruti
# 2    Petrol  Hatchback    80,000         Automatic         2   Maruti
# 3    Petrol  Hatchback    44,392            Manual         1  Hyundai
# 4    Petrol  Hatchback    40,000         Automatic         1   Maruti
#
#                model  model_year     price registration_year seats_count  \
# 0        Hyundai i20        2015  510000.0              2015           5
# 1       Maruti Swift        2012  381000.0              2012           5
# 2     Maruti Celerio        2016  320000.0              2016           5
# 3  Hyundai Grand i10        2017  420000.0              2017           5
# 4     Maruti Wagon R        2016  350000.0              2016           5
#
#   RDO_no car_engine_cc mileage   color gear_box
# 0   RJ13          1396   22.54  Others        6
# ...

# %% [markdown]
# Kolkata

# %%
import pandas as pd

# Define the file path to your Excel file
file_path = r'C:\Users\Ramanathan\Desktop\Capstone_3\kolkata_cars.xlsx'

# Read the Excel file into a DataFrame
kolkata_data = pd.read_excel(file_path)

# Display the first row of the DataFrame, which includes the column headers
print(kolkata_data.head(1))

# Optionally, display the DataFrame in a well-formatted table view (only useful in Jupyter or notebooks)
from IPython.display import display
display(kolkata_data.head(1))  # Displays a neat table format in notebooks
# Out:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                        new_car_specs  \
# 0  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                            car_links
# 0  https://www.cardekho.com/used-car-details/used...
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                        new_car_specs  \
# ...

# %%
fuel_type=[]
body_type=[]
kilometer=[]
transmission_type=[]
owner_no=[]
brand=[]
model=[]
model_year=[]
price=[]
registration_year=[]
seats_count=[]
RDO_no=[]
engine_cc=[]
mileage=[]
max_power=[]
color=[]
car_engine_cc=[]
gear_box=[]
seating_capacity=[]
top_speed=[]
pickup_speed=[]
tyre_type=[]

for i in range(kolkata_data.shape[0]):
    dic_1=kolkata_data['new_car_detail'][i]
    dic_2=kolkata_data['new_car_overview'][i]
    dic_3=kolkata_data['new_car_specs'][i]
    
    res = ast.literal_eval(dic_1)
    res_1 = ast.literal_eval(dic_2)
    res_2 = ast.literal_eval(dic_3)
    
    fuel_type.append(res['ft'])
    body_type.append(res['bt'])
    kilometer.append(res['km'])
    transmission_type.append(res['transmission'])
    owner_no.append(res['ownerNo'])
    brand.append(res['oem'])
    model.append(res['model'])
    model_year.append(res['modelYear'])
    price.append(float(res['price'][2:-5])*100000)
    
    try:
        registration_year.append(res_1['top'][0]['value'][-4:])
    except:
        registration_year.append(np.nan)
    try:
        seats_count.append(res_1['top'][3]['value'][0])
    except:
        seats_count.append(np.nan)
    try:
        RDO_no.append(res_1['top'][5]['value'])
    except:
        RDO_no.append(np.nan)
    try:
        engine_cc.append(res_1['top'][7]['value'][:-3])
    except:
        engine_cc.append(np.nan)
    mileage.append(res_2['top'][0]['value'][:-5])
    try:
        max_power.append(res_2['top'][2]['value'][:-3])
    except:
        max_power.append(np.nan)
    color.append(res_2['data'][0]['list'][0]['value'])
    try:
        if (res_2['data'][0]['list'][2]['value']).isnumeric():
            car_engine_cc.append(res_2['data'][0]['list'][2]['value'])
        else:
            car_engine_cc.append(res_2['data'][0]['list'][1]['value'])
    except:
        car_engine_cc.append(np.nan)
    try:
        gear_box.append(res_2['data'][2]['list'][0]['value'][0])
    except:
        gear_box.append(np.nan)
    try:
        seating_capacity.append(res_2['data'][2]['list'][2]['value'])
    except:
        seating_capacity.append(np.nan)
    try:
        top_speed.append(res_2['data'][2]['list'][7]['value'])
    except:
        top_speed.append(np.nan)
    try:
        pickup_speed.append(res_2['data'][2]['list'][8]['value'])
    except:
        pickup_speed.append(np.nan)
    try:
        tyre_type.append(res_2['data'][2]['list'][9]['value'])
    except:
        tyre_type.append(np.nan)

        
kolkata_data['fuel_type']=fuel_type
kolkata_data['body_type']=body_type
kolkata_data['kilometer']=kilometer
kolkata_data['transmission_type']=transmission_type
kolkata_data['owner_no']=owner_no
kolkata_data['brand']=brand
kolkata_data['model']=model
kolkata_data['model_year']=model_year
kolkata_data['price']=price
kolkata_data['registration_year']=registration_year
kolkata_data['seats_count']=seats_count
kolkata_data['RDO_no']=RDO_no
kolkata_data['engine_cc']=engine_cc
kolkata_data['mileage']=mileage
kolkata_data['max_power(bhp)']=max_power
kolkata_data['color']=color
kolkata_data['car_engine_cc']=car_engine_cc
kolkata_data['gear_box']=gear_box
kolkata_data['seating_capacity']=seating_capacity
kolkata_data['top_speed']=top_speed
kolkata_data['pickup_speed']=pickup_speed
kolkata_data['tyre_type']=tyre_type

# %%
kolkata_data.columns
# Out:
# Index(['new_car_detail', 'new_car_overview', 'new_car_feature',
#        'new_car_specs', 'car_links', 'fuel_type', 'body_type', 'kilometer',
#        'transmission_type', 'owner_no', 'brand', 'model', 'model_year',
#        'price', 'registration_year', 'seats_count', 'RDO_no', 'engine_cc',
#        'mileage', 'max_power(bhp)', 'color', 'car_engine_cc', 'gear_box',
#        'seating_capacity', 'top_speed', 'pickup_speed', 'tyre_type'],
#       dtype='object')

# %%
kolkata_da=kolkata_data[['fuel_type', 'body_type', 'kilometer',
       'transmission_type', 'owner_no', 'brand', 'model', 'model_year',
       'price', 'registration_year', 'seats_count', 'RDO_no', 'car_engine_cc',
       'mileage',  'color', 'gear_box']]
kolkata_da.head()
# Out:
#   fuel_type  body_type kilometer transmission_type  owner_no    brand  \
# 0    Petrol      Sedan    70,000         Automatic         3   Toyota
# 1    Petrol  Hatchback    23,981            Manual         1   Datsun
# 2    Petrol        SUV     7,100         Automatic         1  Renault
# 3    Petrol  Hatchback    71,574            Manual         2  Hyundai
# 4    Diesel        SUV    50,000         Automatic         2     Audi
#
#            model  model_year      price registration_year seats_count RDO_no  \
# 0   Toyota Camry        2014   975000.0              2014           5   WB02
# 1  Datsun RediGO        2017   266000.0              2017           5   WB24
# 2  Renault Kiger        2021   595000.0              2021           5   WB06
# 3    Hyundai i20        2011   223000.0              2012           5   WB06
# 4        Audi Q3        2014  1200000.0              2014           5   WB02
#
#   car_engine_cc mileage  color gear_box
# 0          2494   19.16  White        6
# ...

# %% [markdown]
# Fetching location

# %%
# Adding a 'location' column to each DataFrame with the respective city names
bangalore_data.loc[:, 'location'] = "bangalore"
chennai_data.loc[:, 'location'] = "chennai"
delhi_data.loc[:, 'location'] = "delhi"
hyderabad_data.loc[:, 'location'] = "hyderabad"
jaipur_data.loc[:, 'location'] = "jaipur"
kolkata_data.loc[:, 'location'] = "kolkata"

# %% [markdown]
# Merging all datas

# %%
all_data=pd.concat([bangalore_da,chennai_da,delhi_da,hyderabad_da,jaipur_da,kolkata_da]).reset_index()
all_data.shape
# Out:
# (8369, 18)

# %%
all_data.drop(columns="index",inplace=True)

# %%
all_data.head()
# Out:
#   fuel_type  body_type kilometer transmission_type  owner_no    brand  \
# 0    Petrol  Hatchback  1,20,000            Manual         3   Maruti
# 1    Petrol        SUV    32,706            Manual         2     Ford
# 2    Petrol  Hatchback    11,949            Manual         1     Tata
# 3    Petrol      Sedan    17,794            Manual         1  Hyundai
# 4    Diesel        SUV    60,000            Manual         1   Maruti
#
#                 model  model_year     price registration_year seats_count  \
# 0      Maruti Celerio        2015  400000.0              2015           5
# 1       Ford Ecosport        2018  811000.0              2018           5
# 2          Tata Tiago        2018  585000.0              2018           5
# 3       Hyundai Xcent        2014  462000.0              2014           5
# 4  Maruti SX4 S Cross        2015  790000.0              2015           5
#
#   RDO_no car_engine_cc mileage   color gear_box   location
# ...

# %% [markdown]
# Calculating age

# %%
all_data['registration_year'].unique()
# Out:
# array(['2015', '2018', '2014', '2020', '2017', '2021', '2019', '2022',
#        '2016', '2011', '2009', '2013', '2010', '2008', '2006', '2012',
#        '2005', '2007', '2023', 'ance', '2004', '2003', '2002', 'sive',
#        'arty', 'able'], dtype=object)

# %%
all_data['model_year'].unique()
# Out:
# array([2015, 2018, 2014, 2020, 2017, 2021, 2019, 2022, 2016, 2011, 2009,
#        2013, 2010, 2008, 2006, 2012, 2005, 2007, 2023, 1995, 1998, 2004,
#        2003, 2001, 2002, 2000, 1985, 1997, 1999], dtype=int64)

# %%
model_year_merge=all_data[all_data['registration_year'].isin(['ance','sive','arty', 'able'])]['model_year']

# %%
all_data['registration_year'].unique()
# Out:
# array(['2015', '2018', '2014', '2020', '2017', '2021', '2019', '2022',
#        '2016', '2011', '2009', '2013', '2010', '2008', '2006', '2012',
#        '2005', '2007', '2023', 'ance', '2004', '2003', '2002', 'sive',
#        'arty', 'able'], dtype=object)

# %%
all_data['registration_year'] = pd.to_numeric(all_data['registration_year'], errors='coerce')

all_data['registration_year'] = all_data['registration_year'].fillna(0).astype(int)

# %%
def age(x):
    new=(2023 - x)
    return new
all_data['age']=all_data['registration_year'].apply(age)

# %% [markdown]
# Engine CC

# %%
all_data['car_engine_cc'].value_counts()
# Out:
# car_engine_cc
# 1197    1604
# 998      639
# 1199     489
# 1497     451
# 1248     420
#         ...
# 3597       1
# 2200       1
# 2997       1
# 1108       1
# 2489       1
# Name: count, Length: 150, dtype: int64

# %%
all_data['car_engine_cc'].unique()
# Out:
# array(['998', '1497', '1199', '1197', '1248', '1956', '1198', '1462',
#        '2179', '1950', '1396', '1995', '1498', '4663', '1086', '1991',
#        '1968', '1998', '2982', '1461', '1797', '796', '1353', '2925',
#        '2987', '2967', '999', '1341', '1496', '1582', '1798', '1120',
#        '1969', '1451', '814', '1999', '1591', '1397', '1368', '1598',
#        '3198', '1196', '2993', '2755', '2143', '2354', '1332', '2199',
#        '1997', '1499', '2148', '2696', '1364', '2494', '1373', '1299',
#        '1061', '1493', '2497', '1495', '1590', '1896', '1330', '1781',
#        '1390', '1194', '2953', '1399', '1595', 'Power', '2496',
#        '210AH Lithium Ion', '0', '1984', nan, '2694', '1298', '2362',
#        '2198', '1599', '993', '2393', '1389', '1597', '2498', '2523',
#        '1586', '995', '2499', '2998', '72', '1589', '624', '1596', '799',
#        '3597', '2184', '1405', '5000', '1422', '1047', '2200', '2996',
# ...

# %%
drop_data=all_data[all_data['car_engine_cc'].isin(['210AH Lithium Ion','Power','72'])]
all_data.drop(drop_data.index,inplace=True)

# %%
k='720'
all_data.loc[all_data['car_engine_cc']=='72','car_engine_cc']=k

# %%
all_data.head()
# Out:
#   fuel_type  body_type kilometer transmission_type  owner_no    brand  \
# 0    Petrol  Hatchback  1,20,000            Manual         3   Maruti
# 1    Petrol        SUV    32,706            Manual         2     Ford
# 2    Petrol  Hatchback    11,949            Manual         1     Tata
# 3    Petrol      Sedan    17,794            Manual         1  Hyundai
# 4    Diesel        SUV    60,000            Manual         1   Maruti
#
#                 model  model_year     price  registration_year seats_count  \
# 0      Maruti Celerio        2015  400000.0               2015           5
# 1       Ford Ecosport        2018  811000.0               2018           5
# 2          Tata Tiago        2018  585000.0               2018           5
# 3       Hyundai Xcent        2014  462000.0               2014           5
# 4  Maruti SX4 S Cross        2015  790000.0               2015           5
#
#   RDO_no car_engine_cc mileage   color gear_box   location  age
# ...

# %%
all_data['fuel_type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'Lpg', 'Cng', 'Electric'], dtype=object)

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8364 entries, 0 to 8368
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   fuel_type          8364 non-null   object
#  1   body_type          8364 non-null   object
#  2   kilometer          8364 non-null   object
#  3   transmission_type  8364 non-null   object
#  4   owner_no           8364 non-null   int64
#  5   brand              8364 non-null   object
#  6   model              8364 non-null   object
#  7   model_year         8364 non-null   int64
#  8   price              8364 non-null   float64
#  9   registration_year  8364 non-null   int32
#  10  seats_count        8364 non-null   object
#  11  RDO_no             8364 non-null   object
#  12  car_engine_cc      8307 non-null   object
#  13  mileage            8364 non-null   object
#  14  color              8364 non-null   object
#  15  gear_box           8327 non-null   object
# ...

# %% [markdown]
# Null Percentage

# %%
null_percentage=(all_data.isnull().mean()*100).round(2)
pd.DataFrame({
    'columns':null_percentage.index,
    'null_percentage':null_percentage.values
}).sort_values('null_percentage',ascending=False)
# Out:
#               columns  null_percentage
# 12      car_engine_cc             0.68
# 15           gear_box             0.44
# 0           fuel_type             0.00
# 1           body_type             0.00
# 16           location             0.00
# 14              color             0.00
# 13            mileage             0.00
# 11             RDO_no             0.00
# 10        seats_count             0.00
# 9   registration_year             0.00
# 8               price             0.00
# 7          model_year             0.00
# 6               model             0.00
# 5               brand             0.00
# 4            owner_no             0.00
# 3   transmission_type             0.00
# 2           kilometer             0.00
# 17                age             0.00

# %%
all_data.isnull().sum()
# Out:
# fuel_type             0
# body_type             0
# kilometer             0
# transmission_type     0
# owner_no              0
# brand                 0
# model                 0
# model_year            0
# price                 0
# registration_year     0
# seats_count           0
# RDO_no                0
# car_engine_cc        57
# mileage               0
# color                 0
# gear_box             37
# location              0
# age                   0
# dtype: int64

# %%
lis=[]
for i in all_data.columns:
    zero_percentage=((all_data[i]== 0).mean().round(4))
    lis.append((i,zero_percentage))
zero_percent=pd.DataFrame(lis,columns=('columns','zero_percentage')).sort_values('zero_percentage',ascending=False)
zero_percent
# Out:
#               columns  zero_percentage
# 17                age           0.0139
# 9   registration_year           0.0060
# 4            owner_no           0.0038
# 2           kilometer           0.0000
# 3   transmission_type           0.0000
# 5               brand           0.0000
# 6               model           0.0000
# 7          model_year           0.0000
# 8               price           0.0000
# 1           body_type           0.0000
# 10        seats_count           0.0000
# 11             RDO_no           0.0000
# 12      car_engine_cc           0.0000
# 13            mileage           0.0000
# 14              color           0.0000
# 15           gear_box           0.0000
# 16           location           0.0000
# 0           fuel_type           0.0000

# %%
lis=[]
i=0
for i in all_data.columns:
    k=(all_data[i]==0).sum()
    print(i,':',k)
# Out:
# fuel_type : 0
# body_type : 0
# kilometer : 0
# transmission_type : 0
# owner_no : 32
# brand : 0
# model : 0
# model_year : 0
# price : 0
# registration_year : 50
# seats_count : 0
# RDO_no : 0
# car_engine_cc : 0
# mileage : 0
# color : 0
# gear_box : 0
# location : 0
# age : 116

# %%
all_data['kilometer'].unique()
# Out:
# array(['1,20,000', '32,706', '11,949', ..., '53,562', '32,190',
#        '1,51,000'], dtype=object)

# %%
all_data['kilometer']=all_data['kilometer'].str.replace(',', '').astype(int)

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8364 entries, 0 to 8368
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   fuel_type          8364 non-null   object
#  1   body_type          8364 non-null   object
#  2   kilometer          8364 non-null   int32
#  3   transmission_type  8364 non-null   object
#  4   owner_no           8364 non-null   int64
#  5   brand              8364 non-null   object
#  6   model              8364 non-null   object
#  7   model_year         8364 non-null   int64
#  8   price              8364 non-null   float64
#  9   registration_year  8364 non-null   int32
#  10  seats_count        8364 non-null   object
#  11  RDO_no             8364 non-null   object
#  12  car_engine_cc      8307 non-null   object
#  13  mileage            8364 non-null   object
#  14  color              8364 non-null   object
#  15  gear_box           8327 non-null   object
# ...

# %%
all_data['transmission_type'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
all_data['owner_no'].unique()
# Out:
# array([3, 2, 1, 4, 5, 0], dtype=int64)

# %%
all_data['seats_count']=all_data['seats_count'].astype(int)

# %%
def rdo_(x):
    for i in x:
        if len(str(i))==4:
            pass
        else:
            print(np.nan)

# %%
x=['KA51', 'KA05', 'KA03', 'KA53', 'KA04', 'First Owner', 'KA01',
       'OD02', 'KA41', 'KA02', 'Third Owner', 'Second Owner', 'HR26',
       'WB38', 'KA47', 'KA19', 'KA50', 'KA09', 'PY01', 'KA66', 'KA20']
for i in x:
    k=[len(str(i))==4]
    print(k)
# Out:
# [True]
# [True]
# [True]
# [True]
# [True]
# [False]
# [True]
# [True]
# [True]
# [True]
# [False]
# [False]
# [True]
# [True]
# [True]
# [True]
# [True]
# [True]
# [True]
# [True]
# [True]

# %%
# all_data[all_data['registration_year']==0]
all_data['RDO_no'].value_counts()
all_data['RDO_no'].unique()
# Out:
# array(['KA51', 'KA05', 'KA03', 'KA53', 'KA04', 'First Owner', 'KA01',
#        'OD02', 'KA41', 'KA02', 'Third Owner', 'Second Owner', 'HR26',
#        'WB38', 'KA47', 'KA19', 'KA50', 'KA09', 'PY01', 'KA66', 'KA20',
#        'KA52', 'KA25', 'KA27', 'TN09', 'KA13', 'MH46', 'KA42', 'KA12',
#        'KL07', 'Fourth Owner', 'KA55', 'KA07', 'KA17', 'KA16', 'TN33',
#        'KA06', 'KA22', 'KA14', 'KA35', 'KA21', 'KA32', 'KL24', 'KA63',
#        'KA26', 'KA11', 'KA36', 'KA40', 'Fifth Owner', 'DL14', 'UP32',
#        'KA34', 'KA45', '796 cc', 'AP39', 'DL8C', 'MH48', 'TN14', 'MH03',
#        'TN10', 'WB26', 'WB08', 'MH31', 'KL60', 'WB12', 'VK28', 'UP16',
#        'KL58', 'MP20', 'KA59', 'KA18', 'KA68', 'KA31', 'UP14', 'GJ06',
#        'UP70', 'DL03', '1999 cc', 'AP28', 'HR51', 'RJ05', 'HR13', 'CH01',
#        'MH04', 'JH01', 'KA33', 'TS07', 'TN02', 'TN04', 'TN22', 'TN11',
#        'TN06', 'TN05', 'TN07', 'TN19', 'TN01', 'TN24', 'TN18', 'TN03',
# ...

# %%
all_data.loc[all_data['RDO_no'].isin(['First Owner','Third Owner', 'Second Owner','Fourth Owner','Fifth Owner',
                                    '796 cc','1999 cc', 'Manual','1197 cc', '998 cc', 'Automatic','2993 cc','1799 cc',
                                     '2446 cc','999 cc','993 cc','1995 cc','1061 cc']),['RDO_no']]=np.nan

# %%
all_data['RDO_no'].isnull().sum()
# Out:
# 911

# %%
# all_data['car_engine_cc'].value_counts()
all_data[(all_data['car_engine_cc'].isin(['0']))|(all_data['car_engine_cc'].isnull()==True)]
# Out:
#      fuel_type  body_type  kilometer transmission_type  owner_no    brand  \
# 575   Electric  Hatchback        150         Automatic         1       MG
# 600     Petrol  Hatchback      60000            Manual         3  Hyundai
# 601   Electric        SUV      10000         Automatic         1     Tata
# 623   Electric        SUV      30000         Automatic         1     Tata
# 624   Electric        SUV      21236         Automatic         1     Tata
# ...        ...        ...        ...               ...       ...      ...
# 8163  Electric        SUV      53700         Automatic         1     Tata
# 8168  Electric        SUV      31100         Automatic         1     Tata
# 8170  Electric        SUV      26000         Automatic         1     Tata
# 8178  Electric      Sedan      48277         Automatic         1     Tata
# 8260    Petrol      Sedan      28000            Manual         1     Ford
#
#                     model  model_year      price  registration_year  \
# ...

# %%
for i,j in zip(all_data.loc[(all_data['car_engine_cc'].isin(['0']))|(all_data['car_engine_cc'].isna()==True)]['brand'],all_data.loc[(all_data['car_engine_cc'].isin(['0']))|(all_data['car_engine_cc'].isna()==True)]['model']):
    value=all_data.loc[(all_data['brand'] == i)&(all_data['model'] == j)]['car_engine_cc'].value_counts().index[0]
    all_data.loc[(all_data['car_engine_cc'].isin(['0']))|(all_data['car_engine_cc'].isnull()==True),'car_engine_cc']=value
    print(value)
# Out:
# 0
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086
# 1197
# 1086
# 796
# 1086
# 1086
# 1086
# 1197
# 1995
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086
# 1197
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086
# 1496
# 1086
# 1086
# 1086
# 1086
# 1086
# 1496
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086
# 3198
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086
# 1197
# 1197
# 2354
# 1086
# 1086
# 1197
# 1086
# 2354
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086
# 1086

# %%
all_data[all_data['car_engine_cc']=='0']
# Out:
# Empty DataFrame
# Columns: [fuel_type, body_type, kilometer, transmission_type, owner_no, brand, model, model_year, price, registration_year, seats_count, RDO_no, car_engine_cc, mileage, color, gear_box, location, age]
# Index: []

# %%
all_data['car_engine_cc']=all_data['car_engine_cc'].astype(int)

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8364 entries, 0 to 8368
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   fuel_type          8364 non-null   object
#  1   body_type          8364 non-null   object
#  2   kilometer          8364 non-null   int32
#  3   transmission_type  8364 non-null   object
#  4   owner_no           8364 non-null   int64
#  5   brand              8364 non-null   object
#  6   model              8364 non-null   object
#  7   model_year         8364 non-null   int64
#  8   price              8364 non-null   float64
#  9   registration_year  8364 non-null   int32
#  10  seats_count        8364 non-null   int32
#  11  RDO_no             7453 non-null   object
#  12  car_engine_cc      8364 non-null   int32
#  13  mileage            8364 non-null   object
#  14  color              8364 non-null   object
#  15  gear_box           8327 non-null   object
# ...

# %%
# all_data['mileage'].unique()
d=all_data[all_data['mileage']=='']
all_data.drop(d.index,inplace=True)

# %%
all_data['mileage']=all_data['mileage'].astype(float)

# %%
all_data['color'].unique()
# d=all_data[all_data['mileage']=='']
# Out:
# array(['White', 'Red', 'Others', 'Gray', 'Grey', 'Maroon', 'Orange',
#        'Silver', 'Blue', 'Brown', 'Yellow', 'Black', 'Golden', 'Green',
#        'O Purple', 'Other', 'Gold', 'TITANIUM GREY', 'Violet',
#        'MODERN STEEL METALLIC', 'PLATINUM WHITE', 'Golden Brown',
#        'Aurora Black Pearl', 'Beige', 'Star Dust', 'Flash Red', 'Purple',
#        'PLATINUM WHITE PEARL', 'Wine Red', 'Taffeta White',
#        'Minimal Grey', 'Fiery Red', 'T Wine', 'Prime Star Gaze',
#        'TAFETA WHITE', 'P Black', 'Golden brown', 'METALL',
#        'MET ECRU BEIGE', 'COPPER', 'TITANIUM', 'CHILL', 'Burgundy',
#        'Lunar Silver Metallic', 'SILKY SILVER', 'BERRY RED',
#        'PREMIUM AMBER METALLIC', 'R EARTH', 'PLATINUM SILVER',
#        'ORCHID WHITE PEARL', 'CARNELIAN RED PEARL', 'POLAR WHITE',
#        'BEIGE', 'Medium Blue', 'Alabaster Silver Metallic',
#        'Carbon Steel', 'Cavern Grey', 'ESPRESO_BRWN', 'Pearl White',
# ...

# %%
all_data['gear_box'].unique()
# Out:
# array(['5', '6', '7', '4', '8', '9', 'C', 'F', nan, 'I', 'i', 'A', 'R',
#        'S', 'E', '1', 'M', 'e'], dtype=object)

# %%
all_data[all_data['gear_box']=='e']
# Out:
#      fuel_type body_type  kilometer transmission_type  owner_no   brand  \
# 7945    Petrol       SUV       4732         Automatic         1  Maruti
#
#                     model  model_year      price  registration_year  \
# 7945  Maruti Grand Vitara        2023  1900000.0               2023
#
#       seats_count RDO_no  car_engine_cc  mileage color gear_box location  age
# 7945            5   WB08           1490    27.97  Blue        e  kolkata    0

# %%
mappings = {
    '5':'5',
    '6':'6',
    '7':'7',
    '4':'4',
    '8':'8',
    '9':'9',
    'C':'4',
    'F':'6',
    'nan':'5',
    'I':'5',
    'i':'5',
    'A':'5',
    'R':'6',
    'S':'5',
    'E':'6',
    '1':'4',
    'M':'4',
    'e':'6'}
 
all_data['gear_box'] =all_data['gear_box'].map(mappings)
all_data
# Out:
#      fuel_type  body_type  kilometer transmission_type  owner_no  \
# 0       Petrol  Hatchback     120000            Manual         3
# 1       Petrol        SUV      32706            Manual         2
# 2       Petrol  Hatchback      11949            Manual         1
# 3       Petrol      Sedan      17794            Manual         1
# 4       Diesel        SUV      60000            Manual         1
# ...        ...        ...        ...               ...       ...
# 8364    Petrol  Hatchback      10000            Manual         1
# 8365    Petrol  Hatchback     120000            Manual         1
# 8366    Petrol      Sedan      50000         Automatic         3
# 8367    Petrol  Hatchback      40000            Manual         1
# 8368    Diesel        SUV     120000            Manual         2
#
#               brand                  model  model_year     price  \
# 0            Maruti         Maruti Celerio        2015  400000.0
# ...

# %%
all_data.loc[(all_data['gear_box'].isnull()==True),'gear_box']='5'

# %%
all_data[all_data['gear_box'].isnull()]
# Out:
# Empty DataFrame
# Columns: [fuel_type, body_type, kilometer, transmission_type, owner_no, brand, model, model_year, price, registration_year, seats_count, RDO_no, car_engine_cc, mileage, color, gear_box, location, age]
# Index: []

# %%
all_data.shape
# Out:
# (8338, 18)

# %%
all_data.to_csv('cardekho.csv',index=False)

# %%
all_data
# Out:
#      fuel_type  body_type  kilometer transmission_type  owner_no  \
# 0       Petrol  Hatchback     120000            Manual         3
# 1       Petrol        SUV      32706            Manual         2
# 2       Petrol  Hatchback      11949            Manual         1
# 3       Petrol      Sedan      17794            Manual         1
# 4       Diesel        SUV      60000            Manual         1
# ...        ...        ...        ...               ...       ...
# 8364    Petrol  Hatchback      10000            Manual         1
# 8365    Petrol  Hatchback     120000            Manual         1
# 8366    Petrol      Sedan      50000         Automatic         3
# 8367    Petrol  Hatchback      40000            Manual         1
# 8368    Diesel        SUV     120000            Manual         2
#
#               brand                  model  model_year     price  \
# 0            Maruti         Maruti Celerio        2015  400000.0
# ...
